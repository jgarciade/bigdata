# %%
import pandas as pd
import json
import numpy as np
import collections
from collections import defaultdict
import itertools
from operator import itemgetter
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
def count_language_from_survey(survey_path, result_path):
    df=pd.read_json(survey_path)

    splitlista=[]
    for i in df['programming_languages']:
        if i is not None:
            for  e in i:
                splitlista.append(e)

    splitlista
    minuscula=[]
    [minuscula.append(i.lower()) for i in splitlista]
    lista = [row.split(',') for row in minuscula]
    conteo=[[key, len(list(group))] for key, group in itertools.groupby(sorted(lista, key=itemgetter(0)), itemgetter(0))]
    conteo.sort(key=lambda x: x[-1])
    conteo= conteo[-5:][::-1]
    result=[]
    for language in conteo:
        result.append({language[0]: language[1]})

    with open(result_path, 'w') as outfile:
        json.dump(result, outfile, indent=4)
    return result
        
results16=count_language_from_survey('clean_files/2016.json', 'results_2016.json')
results17=count_language_from_survey('clean_files/2017.json', 'results_2017.json')

# %%
def count_language_from_survey(survey_path, result_path):
    df2011=pd.read_json(survey_path)
    splitlista=[]
    [splitlista.append(e) for i in df2011['programming_languages'] for  e in i]
    minuscula=[]
    [minuscula.append(i.lower()) for i in splitlista]
    lista = [row.split(',') for row in minuscula]
    conteo=[[str(key), len(list(group))] for key, group in itertools.groupby(sorted(lista, key=itemgetter(0)), itemgetter(0))]
    conteo.sort(key=lambda x: x[-1])
    conteo= conteo[-5:][::-1]
    result=[]
    for language in conteo:
        result.append({language[0]: language[1]})
        

    with open(result_path, 'w') as outfile:
        json.dump(result, outfile, indent=4)
        
    return result
        
results11= count_language_from_survey('clean_files/2011.json', 'results_2011.json')
results12= count_language_from_survey('clean_files/2012.json', 'results_2012.json')
results13= count_language_from_survey('clean_files/2013.json', 'results_2013.json')
results14= count_language_from_survey('clean_files/2014.json', 'results_2014.json')
results15= count_language_from_survey('clean_files/2015.json', 'results_2015.json')

# %%
dataframe11 = {}

for result in results11:
    for (key, value) in result.items():
        data = {key: [value]}
        dataframe11.update(**data)

df11=pd.DataFrame(dataframe)
df11.head()
# Out:
#     sql  javascript   css    c#  java
# 0  1614        1421  1357  1353   913

# %%
dataframe12 = {}

for result12 in results12:
    for (key, value) in result12.items():
        data = {key: [value]}
        dataframe12.update(**data)

df12=pd.DataFrame(dataframe12)
df12.head()
# Out:
#     sql  javascript   css    c#  java
# 0  3295        3128  2825  2471  2349

# %%
dataframe13 = {}

for result13 in results13:
    for (key, value) in result13.items():
        data = {key: [value]}
        dataframe13.update(**data)

df13=pd.DataFrame(dataframe13)
df13.head()
# Out:
#    javascript   sql  jquery    c#  java
# 0        4744  4595    4354  3028  3021

# %%
dataframe14 = {}

for result14 in results14:
    for (key, value) in result14.items():
        data = {key: [value]}
        dataframe14.update(**data)

df14=pd.DataFrame(dataframe14)
df14.head()
# Out:
#    javascript   sql  java    c#   php
# 0        3784  3469  2480  2379  1713

# %%
dataframe15 = {}

for result15 in results15:
    for (key, value) in result15.items():
        data = {key: [value]}
        dataframe15.update(**data)

df15=pd.DataFrame(dataframe15)
df15.head()
# Out:
#    javascript   sql  java    c#   php
# 0       11964  9440  8219  6949  6530

# %%
dataframe16 = {}

for result16 in results16:
    for (key, value) in result16.items():
        data = {key: [value]}
        dataframe16.update(**data)

df16=pd.DataFrame(dataframe16)
df16.head()
# Out:
#     javascript    sql   java    php   python
# 0        22606  21664  13657  12177    11374

# %%
dataframe17 = {}

for result17 in results17:
    for (key, value) in result17.items():
        data = {key: [value]}
        dataframe17.update(**data)

df17=pd.DataFrame(dataframe17)
df17.head()
# Out:
#      sql   javascript   python   php   java
# 0  18466        17159    10719  9765   8622

# %%
df11.plot(kind='bar');
df12.plot(kind='bar');
df13.plot(kind='bar');
df14.plot(kind='bar');
df15.plot(kind='bar');
df16.plot(kind='bar');
df17.plot(kind='bar');
